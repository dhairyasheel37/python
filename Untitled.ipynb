# %%
print("Hello , World")
# Out:
# Hello , World

# %%
name = input("Enter the your name : ")
print("Hello, "+name)
print(type(name))
# Out:
# Enter the your name :
# Hello,
# <class 'str'>

# %%
name = input("Enter the your name : ")
print("Hello, "+name)
print(type(name))
# Out:
# Enter the your name :  Dhairyasheel Gaikwad
# Hello, Dhairyasheel Gaikwad
# <class 'str'>

# %%
num = (input("Enter the number : "))
print(num)
print(type(num))
# Out:
# Enter the number :  50
# 50
# <class 'str'>

# %%
# but is number
# by default it is string 
# Because int is not defined
# below is error

# %%
num = num + 2
print(num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 num = num + 2
#       2 print(num)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Therefore

# %%
num = int((input("Enter the number : ")))
print(num)
print(type(num))
# Out:
# Enter the number :  10
# 10
# <class 'int'>

# %%
num = int((input("Enter the number : ")))
print(num)
print(type(num))
num = num + 10
print(num)
# Out:
# Enter the number :  4
# 4
# <class 'int'>
# 14

# %%
num = float((input("Enter the number : ")))
print(num)
print(type(num))
print(num+2)
# Out:
# Enter the number :  10.2
# 10.2
# <class 'float'>
# 12.2

# %%
B_num = bool((input("Enter the number : ")))
print(B_num)
print(type(B_num))
# Out:
# Enter the number :  10
# True
# <class 'bool'>

# %%
# if the cost price 25% of selling price then Find Profit Percentage ?
sp = 100
cp = 25
p = sp - cp
print(p)
# Out:
# 75

# %%
### variables In Python

# %%
a = 10
a = "Hello"
print(a)
# Out:
# Hello

# %%
var1 = 1
var_2 = 2
_var3 = 3
print(var1,var_2,_var3)
# Out:
# 1 2 3

# %%
# 1Var = 1
## THIS IS INVALIDE

# %%
var_1 = 5
print(var_1)
# Out:
# 5

# %%
a = 10
A = 20
print(A)
# Out:
# 20

# %%
def = 5
print(def)
# Out:
#   Cell In[27], line 1
#     def = 5
#         ^
# SyntaxError: invalid syntax

# %%
## ABOVE KEYWORD IS INVADE

# %%
# Data Type in PYTHON

# %%
#) 1 . NUMERIC TYPE
   # int
age = 32
    # float
weight = 80.5
     #Complex -> ex(3+4j) (3+4J)
com = 3 + 4j
print(age,weight,com)
# Out:
# 32 80.5 (3+4j)

# %%
#) 2 . Text Type 
    # str -> String Type

name = "Dhairysheel"
print(name)
# Out:
# Dhairysheel

# %%
#) 3 . Boolean Type 
    # bool -> Example -> True , False

is_boy = True
print(is_boy)
# Out:
# True

# %%
#) 4 . Sequence Type 
    # List 
    # tuple
    # range

List1 = [1,2,3]
Tuple1 = (1,2,3)
dict1 = range(1,15)
print(List1)
print(Tuple1)
print(dict1)
# Out:
# [1, 2, 3]
# (1, 2, 3)
# range(1, 15)

# %%
#) 5 . Mapping Type 
    # Dict -> (Key , Value)
dict1 = {'name':'Varun','age':32,'city':'Kolhapur'}
print(dict1)
# Out:
# {'name': 'Varun', 'age': 32, 'city': 'Kolhapur'}

# %%
#) 6 . Set Type 
    # Set -> Unique data , Unordered
set1 = {1,2,3,4,5,6}
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#) 7. Binary Type 
    # Byte 
    # Bytearray

byte_ = bytearray([1,2,3])
print(byte_)
byte = bytes([1,2,3])
print(type(byte))
print(type(byte_))
# Out:
# bytearray(b'\x01\x02\x03')
# <class 'bytes'>
# <class 'bytearray'>

# %%
#) 8. None Type
    #->special Type
     #->Unizilize data
none_ = None
print(none_)
print(type(none_))
# Out:
# None
# <class 'NoneType'>

# %%
# 8 LECTURE TYPE CASTING

# %%
num1 = (input("Enter the 1 st number : "))
num2 = (input("Enter the 2 nd number : "))
print(num1+num2)
# Out:
# Enter the 1 st number :  10
# Enter the 2 nd number :  20
# 1020

# %%
# it like it string 
# WE should do type castings

# %%
# Explicite type casting

num1 = int(input("Enter the 1 nd number : "))
num2 = int(input("Enter the 2 nd number : "))
print(num1+num2)
# Out:
# Enter the 1 nd number :  15
# Enter the 2 nd number :  202
# 217

# %%
# Implicit TYpe casting do by python
# Python convert the data type Higher order .
num1 = 20
num2 = 25.50
print(num1+num2)
print(num1*num2)
# Out:
# 45.5
# 510.0

# %%
num = 10
f = float(num)
print(f)
print("Float : ")
b = hex(num)
print(b)
print("Hex : ")
c = oct(num)
print(c)
print("Oct : ")
b = bin(num)
print(b)
print("Binary : ")
char = 'A'
e = ord(char)
print(e)
print("Unicode's : ")
e = 65
char = chr(e)
print(char)
print("char")
# Out:
# 10.0
# Float
# 0xa
# Hex
# 0o12
# Oct
# 0b1010
# Binary
# 65
# Unicode's
# A
# char

# %%
# Escape Character 
# / Backlash
# /n New Line
# /t Space
# /r Carriage Return 

# These spcial characters used to repesent non - printable or special characters within  a string

# %%
print("I/'ll go to the college DKTE")
# Out:
# I/'ll go to the college DKTE

# %%
print("Prepare well for 'GATE-2024' exam")
print("Prepare well for \"GATE-2025\" exam")
# Out:
# Prepare well for 'GATE-2024' exam
# Prepare well for "GATE-2025" exam

# %%
a = "Hello,\tSmashers!"
print(a)
# Out:
# Hello,	Smashers!

# %%
x = "no__benifits__of__Study\rHuge_Benefits"
print(x)
# Out:
# Huge_Benefits_of__Study
